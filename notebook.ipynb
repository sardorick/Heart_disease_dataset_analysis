# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\ritth\\code\\Strive\\Strive-Exercises\\Chapter 02\\09. Challenge\\data\\heart.csv")

# %%
data.sample(10)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 127   67    0   2     152   277    0        1       172     0      0.0    2
# 108   50    0   1     120   244    0        1       162     0      1.1    2
# 255   45    1   0     142   309    0        0       147     1      0.0    1
# 215   43    0   0     132   341    1        0       136     1      3.0    1
# 53    44    0   2     108   141    0        1       175     0      0.6    1
# 66    51    1   2     100   222    0        1       143     1      1.2    1
# 78    52    1   1     128   205    1        1       184     0      0.0    2
# 49    53    0   0     138   234    0        0       160     0      0.0    2
# 277   57    1   1     124   261    0        1       141     0      0.3    2
# 116   41    1   2     130   214    0        0       168     0      2.0    1
#
#      caa  thall  output
# 127    1      2       1
# 108    0      2       1
# 255    3      3       0
# 215    0      3       0
# ...

# %% [markdown]
# ## Correlation matrix

# %%
data.corr()["output"].abs().sort_values().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Less importants are fbs, chol, restecg. So we can drop this column by doing Feature Selection

# %% [markdown]
# ## Categorical data visualization

# %%
categoric_var = ['sex', 'cp', 'fbs', 'restecg', 'exng', 'slp', 'caa', 'thall', 'output']

# %%
categoric_axis_name = ["Gender", "Chest Pain Type", "Fasting Blood sugar", "Resting Electrocardiographic Results",
                      "Exercise Induced Angina", "The Slope of ST Segment", "Number of Major Vessels", "Thal", "Target"]

# %%
title_font = {"family" : "arial", "color" : "darkred", "weight" : "bold", "size" : 15}
axis_font = {"family" : "arial", "color" : "darkblue", "weight" : "bold", "size" : 13}

for i, z in list(zip(categoric_var, categoric_axis_name)):
    plt.figure(figsize = (8, 5))
    sns.countplot(i, data = data[categoric_var], hue = "output")
    
    plt.title(i + " - target", fontdict = title_font)
    plt.xlabel(z, fontdict = axis_font)
    plt.ylabel("Target", fontdict = axis_font)
    
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\ritth\software\anaconda\envs\strive\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ritth\software\anaconda\envs\strive\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ## Target or output
# target: Heart disease (1 = no, 0= yes)
#
# #### Sex - Target Variable [0 = Male, 1 = Female]
# female patients are at higher risk for heart attack
#
# #### Cp - Target Variable
# First bar graph has an observation value of 0, asymptomatic pains. This pain was pain that occurred without symptoms.
# If a patient's "cp" variable is 1, 2, or 3, we can say that the risk of heart attack is high.
#
# #### Fbs - Target Variable
# The risk of heart attack is slightly higher in those with a 0 observation value as fasting blood sugar.
# Patients with fasting blood sugar lower than 120 mg/dl can be positioned as risky.
#
# #### Restecg - Target Variable

# %% [markdown]
# ## Numerical data visualization

# %%
numeric_var = ['age', 'trtbps', 'chol', 'thalachh', 'oldpeak']

# %%
for i in numeric_var:
    plt.figure(figsize = (8, 6))
    sns.distplot(data[i], hist_kws = dict(linewidth = 1, edgecolor = "k"), bins = 20)
    
    plt.title(i)
    plt.xlabel(i)

    
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\ritth\software\anaconda\envs\strive\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ritth\software\anaconda\envs\strive\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ##

# %%
numeric_var = ['age', 'trtbps', 'chol', 'thalachh', 'oldpeak', 'output']

# %%
numeric_axis_name = ["Age of the Patient", "Resting Blood Pressure", "Cholesterol", "Maximum Heart Rate Achieved", "ST Depression", "Target"]

# %%
title_font = {"family" : "arial", "color" : "darkred", "weight" : "bold", "size" : 15}
axis_font = {"family" : "arial", "color" : "darkblue", "weight" : "bold", "size" : 13}

for i, z in list(zip(numeric_var, numeric_axis_name)):
    graph = sns.FacetGrid(data[numeric_var], hue = "output", height = 5, )
    graph.map(sns.kdeplot, i, shade = True)
    graph.add_legend()
    
    plt.title(i, fontdict = title_font)
    plt.xlabel(z, fontdict = axis_font)
    
    
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\ritth\software\anaconda\envs\strive\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ritth\software\anaconda\envs\strive\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
